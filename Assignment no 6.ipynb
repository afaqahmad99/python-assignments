# %% [markdown]
# # Question no 1:

# %% [markdown]
# ## Ans: Object Oriented Programming (OOP) is a programming language model in which programs are organized around data, or objects, rather than functions and logic.Object oriented Programming is based on the principles of polymorphism, abstraction, inheritance and encapsulation. In Object Oriented Programming we can solve real world problems.

# %% [markdown]
# # Question no 2:

# %% [markdown]
# ## Ans:
# ## BENEFITS OF OOP:
#
# ### 1)Classes and objects can be invented once and used many times during analysis, design, and programming.
#
# ### 2) Do not need source code for reused class, simply need to know interface.
#
# ### 3) Flexibility through polymorphism.
#
# ### 4) Effective problem solving.

# %% [markdown]
# # Question no 3:
#
# ## Ans:Python method is called on an object, unlike a function. Since we call a method on an object, it can access the data within it. A method may alter an object's state. but Python function usually only operates on it. and then prints something or returns a value.

# %% [markdown]
# # Question no 4:
#
# ## Ans:
# ## CLASS:A class is a template/blueprint/contract that defines what an object's data fields and methods will 	be.
# ## OBJECT: Object is an instance of calss.
# ## BEHAVIOUR: The behavior of an object is defined by its methods, for example like eat(), run(), Bark() etc.
# ## STATE: The states of object are the instances(variables) inside the object that contains the data.

# %%
class  Car():
    def __init__(self,model,color,name,rupees,year):
        self.model=model
        self.color=color
        self.name=name
        self.rupees=rupees 
        self.year=year
        self.companyname="Suzuki" 
        self.tax="2000"
        self.maintance="1000"
    def updatecomp_name(self,a): 
        self.companyname=a
    def  updatetax_rupees(self,b): 
        self.tax=b
    def updatemaintance_rupeees(self,c): 
        self.maintance=c
c1=Car("19","BLUE","CAROLA","200000","2018") 
print(c1.model) 
print(c1.color)
print(c1.name)
print(c1.rupees) 
print(c1.year)
print("OLD COMPANY NAME:"+c1.companyname) 
c1.updatecomp_name("Afaq")
print("NEW  COMPANY  NAME:"+c1.companyname) 
print("OLD  TAX  RATE:"+c1.tax)
c1.updatetax_rupees("3000")
print("NEW TAX RATE:"+c1.tax)
print("OLD MAINTANCE  RATE:::"+c1.maintance) 
c1.updatemaintance_rupeees("1500")
print("NEW MAINTANCE RATE:"+c1.maintance) 
print()

c2=Car("20","GREEN","CAROLA","220000","2019") 
print(c2.model)
print(c2.color) 
print(c2.name) 
print(c2.rupees)
print(c2.year)
print("OLD  COMPANY  NAME:"+c2.companyname) 
c2.updatecomp_name("Car Style")
print ("NEW COMPANY NAME:"+c2.companyname) 
print("OLD  TAX  RATE:"+c2.tax)
c2.updatetax_rupees("3200")
print ("NEW TAX RATE:"+c2.tax)
print("OLD MAINTANCE  RATE:"+c2.maintance) 
c2.updatemaintance_rupeees("1800") 
print("NEW MAINTANCE  RATE:"+c2.maintance) 
print()
                    
c3=Car("16","RED","CAROLA","100000","2012") 
print(c3.model)
print(c3.color) 
print(c3.name) 
print(c3.rupees) 
print(c3.year)
print ("OLD COMPANY NAME:"+c3.companyname) 
c3.updatecomp_name("Stylish Car")
print ("NEW  COMPANY  NAME:"+c3.companyname) 
print("OLD  TAX  RATE:"+c3.tax)
c3.updatetax_rupees("3500")
print ("NEW TAX RATE:"+c3.tax)
print("OLD MAINTANCE RATE:"+c3.maintance) 
c3.updatemaintance_rupeees("2000") 
print ("NEW MAINTANCE  RATE:"+c3.maintance) 
print()
                   
c4=Car ("17","YELLOW","CAROLA","120000","2014") 
print(c4.model)
print(c4.color) 
print(c4.name) 
print(c4.rupees) 
print(c4.year)
print("OLD  COMPANY  NAME:"+c4.companyname) 
c4.updatecomp_name("Old  car")
print ("NEW  COMPANY  NAME:"+c4.companyname) 
print("OLD  TAX  RATE:"+c4.tax) 
c4.updatetax_rupees("4000") 
print ("NEW  TAX  RATE:"+c4.tax)
print("OLD MAINTANCE  RATE:"+c4.maintance) 
c4.updatemaintance_rupeees("3000") 
print("NEW MAINTANCE  RATE:"+c4.maintance) 
print()

c5=Car("18","WHITE","CAROLA","150000","2015") 
print(c5.model)
print(c5.color) 
print(c5.name) 
print(c5.rupees) 
print(c5.year)
print("OLD COMPANY NAME:"+c5.companyname) 
c5.updatecomp_name("New  Fashion  car") 
print ("NEW COMPANY NAME:"+c5.companyname) 
print("OLD  TAX  R4TE:"+c5.tax)
c5.updatetax_rupees("5000")
print ("NEW TAX RA=E:"+c5.tax)
print("OLD MAINTANCE  RATE:"+c5.maintance) 
c5.updatemaintance_rupeees("4500") 
print("NEW MAINTANCE  RATE:"+c5 .maintance)     
print()
# Out:
# 19
# BLUE
# CAROLA
# 200000
# 2018
# OLD COMPANY NAME:Suzuki
# NEW  COMPANY  NAME:Afaq
# OLD  TAX  RATE:2000
# NEW TAX RATE:3000
# OLD MAINTANCE  RATE:::1000
# NEW MAINTANCE RATE:1500
#
# 20
# GREEN
# CAROLA
# 220000
# 2019
# OLD  COMPANY  NAME:Suzuki
# NEW COMPANY NAME:Car Style
# OLD  TAX  RATE:2000
# NEW TAX RATE:3200
# OLD MAINTANCE  RATE:1000
# NEW MAINTANCE  RATE:1800
#
# 16
# RED
# CAROLA
# 100000
# 2012
# OLD COMPANY NAME:Suzuki
# NEW  COMPANY  NAME:Stylish Car
# OLD  TAX  RATE:2000
# NEW TAX RATE:3500
# OLD MAINTANCE RATE:1000
# NEW MAINTANCE  RATE:2000
#
# 17
# YELLOW
# CAROLA
# 120000
# 2014
# OLD  COMPANY  NAME:Suzuki
# NEW  COMPANY  NAME:Old  car
# OLD  TAX  RATE:2000
# NEW  TAX  RATE:4000
# OLD MAINTANCE  RATE:1000
# NEW MAINTANCE  RATE:3000
#
# 18
# WHITE
# CAROLA
# 150000
# 2015
# OLD COMPANY NAME:Suzuki
# NEW COMPANY NAME:New  Fashion  car
# OLD  TAX  R4TE:2000
# NEW TAX RA=E:5000
# OLD MAINTANCE  RATE:1000
# NEW MAINTANCE  RATE:4500
